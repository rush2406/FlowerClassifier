# %% [markdown]
# # Developing an AI application
#
# ## **NOTE:**
#
# This is slightly edited notebook to help you with downloaing and loading image datasets. I have left the exercise parts untouched and you have to fill them, ofcourse. If you have any issue with this notebook, feel free to contact me `avinash` on Slack :D
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/Flowers.png?raw=1' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %% [markdown]
# # Tips, Model Performance, Submission Troubleshooting, etc
#
# The amazing people at Slack have compiled an amazing list of tips for this project. Check it here - [link](https://docs.google.com/document/d/1-MCDPOejsn2hq9EoBzMpzGv9jEdtMWoIwjkAa1cVbSM/edit#heading=h.yspy8tt3f0xe)

# %%
# google colab does not come with torch installed. And also, in course we are using torch 0.4. 
# so following snippet of code installs the relevant version

from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# tcmalloc: large alloc 1073750016 bytes == 0x57d74000 @  0x7f589a8fa2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# we need pillow version of 5.3.0
# we will uninstall the older version first
# !pip uninstall -y Pillow
# install the new one
# !pip install Pillow==5.3.0
# import the new one
import PIL
print(PIL.PILLOW_VERSION)
# this should print 5.3.0. If it doesn't, then restart your runtime:
# Menu > Runtime > Restart Runtime
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# 4.0.0

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import time
import torch
from PIL import Image
import matplotlib.gridspec as gridspec
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms, models
from collections import OrderedDict
import json
from PIL import Image
def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
Image.register_extension = register_extension
def register_extensions(id, extensions): 
  for extension in extensions: register_extension(id, extension)
Image.register_extensions = register_extensions

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). You can [download the data here](https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip). The dataset is split into two parts, training and validation. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. If you use a pre-trained network, you'll also need to make sure the input data is resized to 224x224 pixels as required by the networks.
#
# The validation set is used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks available from `torchvision` were trained on the ImageNet dataset where each color channel was normalized separately. For both sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# we will download the required data files
# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !rm -r flower_data || true
# !unzip -qq flower_data.zip

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# TODO: Define your transforms for the training and validation sets
data_transforms = {
    'training' : transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(30),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406], 
                                                         [0.229, 0.224, 0.225])]),
                                                            
    'validation' : transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])]),
}


# TODO: Load the datasets with ImageFolder
image_datasets = {
    'training' : datasets.ImageFolder(train_dir, transform=data_transforms['training']),
    'validation' : datasets.ImageFolder(valid_dir, transform=data_transforms['validation'])
}

# TODO: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {
    'training' : torch.utils.data.DataLoader(image_datasets['training'], batch_size=64, shuffle=True),
    'validation' : torch.utils.data.DataLoader(image_datasets['validation'], batch_size=64, shuffle=True)
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# TODO: Build and train your network
model = models.densenet121(pretrained=True)

for param in model.parameters():
    param.requires_grad = False
    
input_size = model.classifier.in_features
print(input_size)

classifier = nn.Sequential(
nn.Linear(input_size,1024),
nn.ReLU(),
nn.Dropout(p=0.15),
nn.Linear(1024,512),
nn.ReLU(),
nn.Dropout(p=0.15),
nn.Linear(512,102),
nn.LogSoftmax(dim=1)
)

model.classifier = classifier
total_val_images = len(dataloaders["validation"].batch_sampler) * dataloaders["validation"].batch_size
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(),lr = 0.001)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.class_to_idx = image_datasets['training'].class_to_idx
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.torch/models/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:00<00:00, 76081443.72it/s]
# 1024

# %%
epochs = 40
chk_every = 10
valid_loss_min = np.Inf 

train_losses, test_losses = [], []

for e in range(epochs):
    e_loss=0
    correct=0
    total=0
    prev_chk=0
    val_loss=0
    train_loss=0
    print(f'\nEpoch {e+1} of {epochs}\n----------------------------')
    model.train()
    for ii,(images,labels) in enumerate(dataloaders["training"]):
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        
        output = model.forward(images)
        loss = criterion(output,labels)
        loss.backward()
        optimizer.step()
        
        e_loss+=loss.item()
        _,prediction = torch.max(output.data,1)
        total+=labels.size(0)
        correct += (prediction == labels).sum().item()
        train_loss += loss.item()*images.size(0)
    
    # calculate average training loss over an epoch
        train_loss = train_loss/len(dataloaders['training'].dataset)
        
        itr = (ii + 1)
        if itr % chk_every == 0:
            avg_loss = f'avg. loss: {e_loss/itr:.4f}'
            acc = f'accuracy: {(correct/total) * 100:.2f}%'
            print(f'  Batches {prev_chk:03} to {itr:03}: {avg_loss}, {acc}.')
            prev_chk = (ii + 1)
            
    e_valid_correct=0
    e_valid_total=0
    model.eval()
    with torch.no_grad():
        test_loss = 0
        for ii,(images,labels) in enumerate(dataloaders["validation"]):
            images = images.to(device)
            labels = labels.to(device)
            output = model.forward(images)
            tloss= criterion(output,labels)
            test_loss+=tloss
            val_loss += tloss.item()*images.size(0)
            _, predicted = torch.max(output.data, 1)
            e_valid_total += labels.size(0)
            e_valid_correct += (predicted == labels).sum().item()
            
        print(f"\n\tValidating for epoch {e+1}...")
        correct_perc = 0
        if e_valid_correct > 0:
            correct_perc = (100 * e_valid_correct // e_valid_total)
        if val_loss <= valid_loss_min:
          print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min,val_loss))
          
          # Save Model State on Checkpoint
          state = {
              'state_dict': model.state_dict(),
              'classifier': model.classifier,
              'optimizer_dict': optimizer.state_dict(),
              'class_to_idx': image_datasets['training'].class_to_idx
              }
          torch.save(state,'trial.pt')
          valid_loss_min = val_loss
        print(f'\tAccurately classified {correct_perc:d}% of {total_val_images} images.')
    train_losses.append(train_loss/len(dataloaders['training']))
    test_losses.append(test_loss/len(dataloaders['validation']))   
    val_loss = val_loss/len(dataloaders['validation'].dataset)

print('Done...')       
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Validation loss')
plt.legend(frameon=False)
# Out:
# Epoch 1 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 4.6034, accuracy: 1.88%.
#   Batches 010 to 020: avg. loss: 4.5522, accuracy: 2.97%.
#   Batches 020 to 030: avg. loss: 4.4472, accuracy: 5.89%.
#   Batches 030 to 040: avg. loss: 4.3702, accuracy: 7.70%.
#   Batches 040 to 050: avg. loss: 4.2466, accuracy: 10.00%.
#   Batches 050 to 060: avg. loss: 4.1004, accuracy: 12.71%.
#   Batches 060 to 070: avg. loss: 3.9489, accuracy: 15.02%.
#   Batches 070 to 080: avg. loss: 3.8058, accuracy: 17.05%.
#   Batches 080 to 090: avg. loss: 3.6632, accuracy: 19.39%.
#   Batches 090 to 100: avg. loss: 3.5344, accuracy: 21.36%.
#
# 	Validating for epoch 1...
# Validation loss decreased (inf --> 1558.437753).  Saving model ...
# 	Accurately classified 51% of 832 images.
#
# Epoch 2 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 2.1753, accuracy: 44.69%.
#   Batches 010 to 020: avg. loss: 2.0552, accuracy: 46.80%.
#   Batches 020 to 030: avg. loss: 1.9987, accuracy: 47.14%.
#   Batches 030 to 040: avg. loss: 1.9728, accuracy: 47.42%.
#   Batches 040 to 050: avg. loss: 1.9360, accuracy: 48.53%.
#   Batches 050 to 060: avg. loss: 1.8853, accuracy: 49.58%.
#   Batches 060 to 070: avg. loss: 1.8367, accuracy: 50.76%.
#   Batches 070 to 080: avg. loss: 1.7956, accuracy: 51.82%.
#   Batches 080 to 090: avg. loss: 1.7651, accuracy: 52.62%.
#   Batches 090 to 100: avg. loss: 1.7200, accuracy: 53.77%.
#
# 	Validating for epoch 2...
# Validation loss decreased (1558.437753 --> 867.296827).  Saving model ...
# 	Accurately classified 70% of 832 images.
#
# Epoch 3 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 1.4939, accuracy: 60.47%.
#   Batches 010 to 020: avg. loss: 1.4752, accuracy: 59.06%.
#   Batches 020 to 030: avg. loss: 1.4635, accuracy: 60.00%.
#   Batches 030 to 040: avg. loss: 1.4706, accuracy: 60.23%.
#   Batches 040 to 050: avg. loss: 1.4216, accuracy: 61.59%.
#   Batches 050 to 060: avg. loss: 1.3784, accuracy: 62.89%.
#   Batches 060 to 070: avg. loss: 1.3391, accuracy: 63.93%.
#   Batches 070 to 080: avg. loss: 1.3426, accuracy: 63.87%.
#   Batches 080 to 090: avg. loss: 1.3295, accuracy: 64.36%.
#   Batches 090 to 100: avg. loss: 1.3168, accuracy: 64.56%.
#
# 	Validating for epoch 3...
# Validation loss decreased (867.296827 --> 645.813138).  Saving model ...
# 	Accurately classified 78% of 832 images.
#
# Epoch 4 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 1.0525, accuracy: 69.69%.
#   Batches 010 to 020: avg. loss: 1.0834, accuracy: 69.53%.
#   Batches 020 to 030: avg. loss: 1.0521, accuracy: 71.09%.
#   Batches 030 to 040: avg. loss: 1.0636, accuracy: 70.51%.
#   Batches 040 to 050: avg. loss: 1.0571, accuracy: 70.84%.
#   Batches 050 to 060: avg. loss: 1.0748, accuracy: 70.44%.
#   Batches 060 to 070: avg. loss: 1.0699, accuracy: 70.45%.
#   Batches 070 to 080: avg. loss: 1.0660, accuracy: 70.68%.
#   Batches 080 to 090: avg. loss: 1.0688, accuracy: 70.64%.
#   Batches 090 to 100: avg. loss: 1.0625, accuracy: 70.73%.
#
# 	Validating for epoch 4...
# 	Accurately classified 75% of 832 images.
#
# Epoch 5 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.9503, accuracy: 74.69%.
#   Batches 010 to 020: avg. loss: 0.9646, accuracy: 73.12%.
#   Batches 020 to 030: avg. loss: 0.9464, accuracy: 74.01%.
#   Batches 030 to 040: avg. loss: 0.9363, accuracy: 74.26%.
#   Batches 040 to 050: avg. loss: 0.9460, accuracy: 73.88%.
#   Batches 050 to 060: avg. loss: 0.9339, accuracy: 74.43%.
#   Batches 060 to 070: avg. loss: 0.9195, accuracy: 74.89%.
#   Batches 070 to 080: avg. loss: 0.9286, accuracy: 74.59%.
#   Batches 080 to 090: avg. loss: 0.9329, accuracy: 74.25%.
#   Batches 090 to 100: avg. loss: 0.9371, accuracy: 74.23%.
#
# 	Validating for epoch 5...
# Validation loss decreased (645.813138 --> 474.512314).  Saving model ...
# 	Accurately classified 83% of 832 images.
#
# Epoch 6 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.8261, accuracy: 76.88%.
#   Batches 010 to 020: avg. loss: 0.8583, accuracy: 75.39%.
#   Batches 020 to 030: avg. loss: 0.8488, accuracy: 75.21%.
#   Batches 030 to 040: avg. loss: 0.8568, accuracy: 75.08%.
#   Batches 040 to 050: avg. loss: 0.8823, accuracy: 74.66%.
#   Batches 050 to 060: avg. loss: 0.8983, accuracy: 74.22%.
#   Batches 060 to 070: avg. loss: 0.9001, accuracy: 74.24%.
#   Batches 070 to 080: avg. loss: 0.8980, accuracy: 74.41%.
#   Batches 080 to 090: avg. loss: 0.8906, accuracy: 74.79%.
#   Batches 090 to 100: avg. loss: 0.8804, accuracy: 75.19%.
#
# 	Validating for epoch 6...
# Validation loss decreased (474.512314 --> 455.299596).  Saving model ...
# 	Accurately classified 84% of 832 images.
#
# Epoch 7 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.8295, accuracy: 77.81%.
#   Batches 010 to 020: avg. loss: 0.7838, accuracy: 78.67%.
#   Batches 020 to 030: avg. loss: 0.7935, accuracy: 77.92%.
#   Batches 030 to 040: avg. loss: 0.7790, accuracy: 77.81%.
#   Batches 040 to 050: avg. loss: 0.7912, accuracy: 77.72%.
#   Batches 050 to 060: avg. loss: 0.8003, accuracy: 77.68%.
#   Batches 060 to 070: avg. loss: 0.8020, accuracy: 77.79%.
#   Batches 070 to 080: avg. loss: 0.8114, accuracy: 77.44%.
#   Batches 080 to 090: avg. loss: 0.8196, accuracy: 77.43%.
#   Batches 090 to 100: avg. loss: 0.8237, accuracy: 77.33%.
#
# 	Validating for epoch 7...
# Validation loss decreased (455.299596 --> 400.459144).  Saving model ...
# 	Accurately classified 86% of 832 images.
#
# Epoch 8 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6788, accuracy: 80.78%.
#   Batches 010 to 020: avg. loss: 0.7117, accuracy: 80.08%.
#   Batches 020 to 030: avg. loss: 0.7437, accuracy: 79.79%.
#   Batches 030 to 040: avg. loss: 0.7354, accuracy: 79.88%.
#   Batches 040 to 050: avg. loss: 0.7492, accuracy: 79.81%.
#   Batches 050 to 060: avg. loss: 0.7532, accuracy: 79.74%.
#   Batches 060 to 070: avg. loss: 0.7569, accuracy: 79.58%.
#   Batches 070 to 080: avg. loss: 0.7531, accuracy: 79.65%.
#   Batches 080 to 090: avg. loss: 0.7555, accuracy: 79.51%.
#   Batches 090 to 100: avg. loss: 0.7534, accuracy: 79.50%.
#
# 	Validating for epoch 8...
# 	Accurately classified 85% of 832 images.
#
# Epoch 9 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6995, accuracy: 80.00%.
#   Batches 010 to 020: avg. loss: 0.6913, accuracy: 80.78%.
#   Batches 020 to 030: avg. loss: 0.6921, accuracy: 80.36%.
#   Batches 030 to 040: avg. loss: 0.6892, accuracy: 80.35%.
#   Batches 040 to 050: avg. loss: 0.7164, accuracy: 79.72%.
#   Batches 050 to 060: avg. loss: 0.7149, accuracy: 79.77%.
#   Batches 060 to 070: avg. loss: 0.7169, accuracy: 79.62%.
#   Batches 070 to 080: avg. loss: 0.7111, accuracy: 79.84%.
#   Batches 080 to 090: avg. loss: 0.7136, accuracy: 79.88%.
#   Batches 090 to 100: avg. loss: 0.7114, accuracy: 79.94%.
#
# 	Validating for epoch 9...
# Validation loss decreased (400.459144 --> 355.389290).  Saving model ...
# 	Accurately classified 88% of 832 images.
#
# Epoch 10 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6653, accuracy: 82.97%.
#   Batches 010 to 020: avg. loss: 0.6747, accuracy: 81.09%.
#   Batches 020 to 030: avg. loss: 0.6994, accuracy: 79.84%.
#   Batches 030 to 040: avg. loss: 0.6715, accuracy: 80.82%.
#   Batches 040 to 050: avg. loss: 0.6740, accuracy: 80.84%.
#   Batches 050 to 060: avg. loss: 0.6744, accuracy: 80.91%.
#   Batches 060 to 070: avg. loss: 0.6697, accuracy: 81.07%.
#   Batches 070 to 080: avg. loss: 0.6760, accuracy: 81.02%.
#   Batches 080 to 090: avg. loss: 0.6898, accuracy: 80.69%.
#   Batches 090 to 100: avg. loss: 0.6940, accuracy: 80.58%.
#
# 	Validating for epoch 10...
# 	Accurately classified 87% of 832 images.
#
# Epoch 11 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.8018, accuracy: 77.34%.
#   Batches 010 to 020: avg. loss: 0.7322, accuracy: 78.59%.
#   Batches 020 to 030: avg. loss: 0.7504, accuracy: 78.96%.
#   Batches 030 to 040: avg. loss: 0.7344, accuracy: 79.53%.
#   Batches 040 to 050: avg. loss: 0.7380, accuracy: 79.56%.
#   Batches 050 to 060: avg. loss: 0.7247, accuracy: 80.18%.
#   Batches 060 to 070: avg. loss: 0.7176, accuracy: 80.31%.
#   Batches 070 to 080: avg. loss: 0.7047, accuracy: 80.53%.
#   Batches 080 to 090: avg. loss: 0.6946, accuracy: 80.82%.
#   Batches 090 to 100: avg. loss: 0.6948, accuracy: 80.77%.
#
# 	Validating for epoch 11...
# 	Accurately classified 86% of 832 images.
#
# Epoch 12 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6923, accuracy: 79.06%.
#   Batches 010 to 020: avg. loss: 0.7186, accuracy: 78.83%.
#   Batches 020 to 030: avg. loss: 0.6886, accuracy: 79.64%.
#   Batches 030 to 040: avg. loss: 0.6738, accuracy: 80.08%.
#   Batches 040 to 050: avg. loss: 0.6537, accuracy: 80.88%.
#   Batches 050 to 060: avg. loss: 0.6597, accuracy: 80.99%.
#   Batches 060 to 070: avg. loss: 0.6574, accuracy: 81.09%.
#   Batches 070 to 080: avg. loss: 0.6539, accuracy: 81.37%.
#   Batches 080 to 090: avg. loss: 0.6508, accuracy: 81.65%.
#   Batches 090 to 100: avg. loss: 0.6491, accuracy: 81.55%.
#
# 	Validating for epoch 12...
# Validation loss decreased (355.389290 --> 348.762406).  Saving model ...
# 	Accurately classified 88% of 832 images.
#
# Epoch 13 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6266, accuracy: 82.34%.
#   Batches 010 to 020: avg. loss: 0.5975, accuracy: 83.44%.
#   Batches 020 to 030: avg. loss: 0.5964, accuracy: 83.59%.
#   Batches 030 to 040: avg. loss: 0.6110, accuracy: 83.28%.
#   Batches 040 to 050: avg. loss: 0.6278, accuracy: 82.78%.
#   Batches 050 to 060: avg. loss: 0.6239, accuracy: 83.07%.
#   Batches 060 to 070: avg. loss: 0.6159, accuracy: 83.21%.
#   Batches 070 to 080: avg. loss: 0.6201, accuracy: 82.87%.
#   Batches 080 to 090: avg. loss: 0.6193, accuracy: 82.99%.
#   Batches 090 to 100: avg. loss: 0.6172, accuracy: 83.09%.
#
# 	Validating for epoch 13...
# Validation loss decreased (348.762406 --> 337.972363).  Saving model ...
# 	Accurately classified 89% of 832 images.
#
# Epoch 14 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5952, accuracy: 82.34%.
#   Batches 010 to 020: avg. loss: 0.6177, accuracy: 82.42%.
#   Batches 020 to 030: avg. loss: 0.6242, accuracy: 82.55%.
#   Batches 030 to 040: avg. loss: 0.6187, accuracy: 82.66%.
#   Batches 040 to 050: avg. loss: 0.6081, accuracy: 82.88%.
#   Batches 050 to 060: avg. loss: 0.6103, accuracy: 82.86%.
#   Batches 060 to 070: avg. loss: 0.6098, accuracy: 82.92%.
#   Batches 070 to 080: avg. loss: 0.6026, accuracy: 83.22%.
#   Batches 080 to 090: avg. loss: 0.6021, accuracy: 83.28%.
#   Batches 090 to 100: avg. loss: 0.6083, accuracy: 83.11%.
#
# 	Validating for epoch 14...
# 	Accurately classified 87% of 832 images.
#
# Epoch 15 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5969, accuracy: 82.97%.
#   Batches 010 to 020: avg. loss: 0.5911, accuracy: 83.05%.
#   Batches 020 to 030: avg. loss: 0.6067, accuracy: 82.24%.
#   Batches 030 to 040: avg. loss: 0.6115, accuracy: 82.15%.
#   Batches 040 to 050: avg. loss: 0.6046, accuracy: 82.66%.
#   Batches 050 to 060: avg. loss: 0.6102, accuracy: 82.58%.
#   Batches 060 to 070: avg. loss: 0.6145, accuracy: 82.52%.
#   Batches 070 to 080: avg. loss: 0.6129, accuracy: 82.64%.
#   Batches 080 to 090: avg. loss: 0.6119, accuracy: 82.43%.
#   Batches 090 to 100: avg. loss: 0.6085, accuracy: 82.52%.
#
# 	Validating for epoch 15...
# Validation loss decreased (337.972363 --> 313.666006).  Saving model ...
# 	Accurately classified 90% of 832 images.
#
# Epoch 16 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4993, accuracy: 86.72%.
#   Batches 010 to 020: avg. loss: 0.5519, accuracy: 84.61%.
#   Batches 020 to 030: avg. loss: 0.5469, accuracy: 84.58%.
#   Batches 030 to 040: avg. loss: 0.5653, accuracy: 83.91%.
#   Batches 040 to 050: avg. loss: 0.5624, accuracy: 83.81%.
#   Batches 050 to 060: avg. loss: 0.5713, accuracy: 83.72%.
#   Batches 060 to 070: avg. loss: 0.5793, accuracy: 83.62%.
#   Batches 070 to 080: avg. loss: 0.5787, accuracy: 83.46%.
#   Batches 080 to 090: avg. loss: 0.5755, accuracy: 83.51%.
#   Batches 090 to 100: avg. loss: 0.5794, accuracy: 83.34%.
#
# 	Validating for epoch 16...
# 	Accurately classified 89% of 832 images.
#
# Epoch 17 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.6098, accuracy: 82.34%.
#   Batches 010 to 020: avg. loss: 0.5869, accuracy: 83.28%.
#   Batches 020 to 030: avg. loss: 0.5854, accuracy: 83.59%.
#   Batches 030 to 040: avg. loss: 0.5775, accuracy: 83.52%.
#   Batches 040 to 050: avg. loss: 0.5720, accuracy: 83.69%.
#   Batches 050 to 060: avg. loss: 0.5632, accuracy: 84.04%.
#   Batches 060 to 070: avg. loss: 0.5617, accuracy: 84.29%.
#   Batches 070 to 080: avg. loss: 0.5657, accuracy: 84.24%.
#   Batches 080 to 090: avg. loss: 0.5607, accuracy: 84.39%.
#   Batches 090 to 100: avg. loss: 0.5533, accuracy: 84.55%.
#
# 	Validating for epoch 17...
# Validation loss decreased (313.666006 --> 285.290436).  Saving model ...
# 	Accurately classified 90% of 832 images.
#
# Epoch 18 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5276, accuracy: 84.69%.
#   Batches 010 to 020: avg. loss: 0.5712, accuracy: 83.75%.
#   Batches 020 to 030: avg. loss: 0.6009, accuracy: 82.71%.
#   Batches 030 to 040: avg. loss: 0.5894, accuracy: 83.09%.
#   Batches 040 to 050: avg. loss: 0.5859, accuracy: 83.34%.
#   Batches 050 to 060: avg. loss: 0.5794, accuracy: 83.52%.
#   Batches 060 to 070: avg. loss: 0.5787, accuracy: 83.62%.
#   Batches 070 to 080: avg. loss: 0.5782, accuracy: 83.57%.
#   Batches 080 to 090: avg. loss: 0.5657, accuracy: 83.98%.
#   Batches 090 to 100: avg. loss: 0.5643, accuracy: 84.05%.
#
# 	Validating for epoch 18...
# 	Accurately classified 91% of 832 images.
#
# Epoch 19 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4910, accuracy: 86.25%.
#   Batches 010 to 020: avg. loss: 0.5199, accuracy: 84.84%.
#   Batches 020 to 030: avg. loss: 0.5159, accuracy: 85.36%.
#   Batches 030 to 040: avg. loss: 0.4907, accuracy: 85.74%.
#   Batches 040 to 050: avg. loss: 0.4976, accuracy: 85.59%.
#   Batches 050 to 060: avg. loss: 0.5119, accuracy: 85.05%.
#   Batches 060 to 070: avg. loss: 0.5159, accuracy: 84.87%.
#   Batches 070 to 080: avg. loss: 0.5201, accuracy: 84.79%.
#   Batches 080 to 090: avg. loss: 0.5250, accuracy: 84.70%.
#   Batches 090 to 100: avg. loss: 0.5360, accuracy: 84.55%.
#
# 	Validating for epoch 19...
# 	Accurately classified 89% of 832 images.
#
# Epoch 20 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5382, accuracy: 84.22%.
#   Batches 010 to 020: avg. loss: 0.5399, accuracy: 84.45%.
#   Batches 020 to 030: avg. loss: 0.5533, accuracy: 84.27%.
#   Batches 030 to 040: avg. loss: 0.5567, accuracy: 84.69%.
#   Batches 040 to 050: avg. loss: 0.5593, accuracy: 84.34%.
#   Batches 050 to 060: avg. loss: 0.5635, accuracy: 84.11%.
#   Batches 060 to 070: avg. loss: 0.5615, accuracy: 84.40%.
#   Batches 070 to 080: avg. loss: 0.5569, accuracy: 84.39%.
#   Batches 080 to 090: avg. loss: 0.5533, accuracy: 84.55%.
#   Batches 090 to 100: avg. loss: 0.5480, accuracy: 84.83%.
#
# 	Validating for epoch 20...
# 	Accurately classified 90% of 832 images.
#
# Epoch 21 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5408, accuracy: 83.75%.
#   Batches 010 to 020: avg. loss: 0.4844, accuracy: 85.86%.
#   Batches 020 to 030: avg. loss: 0.5021, accuracy: 85.78%.
#   Batches 030 to 040: avg. loss: 0.5199, accuracy: 85.27%.
#   Batches 040 to 050: avg. loss: 0.5259, accuracy: 85.25%.
#   Batches 050 to 060: avg. loss: 0.5243, accuracy: 85.10%.
#   Batches 060 to 070: avg. loss: 0.5326, accuracy: 84.93%.
#   Batches 070 to 080: avg. loss: 0.5371, accuracy: 84.75%.
#   Batches 080 to 090: avg. loss: 0.5442, accuracy: 84.60%.
#   Batches 090 to 100: avg. loss: 0.5426, accuracy: 84.75%.
#
# 	Validating for epoch 21...
# 	Accurately classified 89% of 832 images.
#
# Epoch 22 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4871, accuracy: 85.31%.
#   Batches 010 to 020: avg. loss: 0.4904, accuracy: 85.78%.
#   Batches 020 to 030: avg. loss: 0.5294, accuracy: 84.64%.
#   Batches 030 to 040: avg. loss: 0.5419, accuracy: 84.30%.
#   Batches 040 to 050: avg. loss: 0.5482, accuracy: 83.94%.
#   Batches 050 to 060: avg. loss: 0.5482, accuracy: 84.04%.
#   Batches 060 to 070: avg. loss: 0.5337, accuracy: 84.40%.
#   Batches 070 to 080: avg. loss: 0.5281, accuracy: 84.59%.
#   Batches 080 to 090: avg. loss: 0.5251, accuracy: 84.69%.
#   Batches 090 to 100: avg. loss: 0.5275, accuracy: 84.73%.
#
# 	Validating for epoch 22...
# 	Accurately classified 89% of 832 images.
#
# Epoch 23 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5737, accuracy: 84.38%.
#   Batches 010 to 020: avg. loss: 0.5605, accuracy: 84.53%.
#   Batches 020 to 030: avg. loss: 0.5451, accuracy: 84.79%.
#   Batches 030 to 040: avg. loss: 0.5491, accuracy: 84.69%.
#   Batches 040 to 050: avg. loss: 0.5483, accuracy: 84.69%.
#   Batches 050 to 060: avg. loss: 0.5415, accuracy: 84.92%.
#   Batches 060 to 070: avg. loss: 0.5318, accuracy: 85.09%.
#   Batches 070 to 080: avg. loss: 0.5335, accuracy: 85.02%.
#   Batches 080 to 090: avg. loss: 0.5293, accuracy: 85.12%.
#   Batches 090 to 100: avg. loss: 0.5296, accuracy: 85.16%.
#
# 	Validating for epoch 23...
# 	Accurately classified 89% of 832 images.
#
# Epoch 24 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5839, accuracy: 84.38%.
#   Batches 010 to 020: avg. loss: 0.5372, accuracy: 85.16%.
#   Batches 020 to 030: avg. loss: 0.5096, accuracy: 85.42%.
#   Batches 030 to 040: avg. loss: 0.5232, accuracy: 85.27%.
#   Batches 040 to 050: avg. loss: 0.5169, accuracy: 85.31%.
#   Batches 050 to 060: avg. loss: 0.5162, accuracy: 85.23%.
#   Batches 060 to 070: avg. loss: 0.5253, accuracy: 85.22%.
#   Batches 070 to 080: avg. loss: 0.5255, accuracy: 85.16%.
#   Batches 080 to 090: avg. loss: 0.5176, accuracy: 85.54%.
#   Batches 090 to 100: avg. loss: 0.5188, accuracy: 85.61%.
#
# 	Validating for epoch 24...
# 	Accurately classified 90% of 832 images.
#
# Epoch 25 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4743, accuracy: 85.31%.
#   Batches 010 to 020: avg. loss: 0.4849, accuracy: 85.39%.
#   Batches 020 to 030: avg. loss: 0.4990, accuracy: 85.52%.
#   Batches 030 to 040: avg. loss: 0.5016, accuracy: 85.70%.
#   Batches 040 to 050: avg. loss: 0.4911, accuracy: 86.06%.
#   Batches 050 to 060: avg. loss: 0.4875, accuracy: 86.12%.
#   Batches 060 to 070: avg. loss: 0.4866, accuracy: 86.34%.
#   Batches 070 to 080: avg. loss: 0.4882, accuracy: 86.39%.
#   Batches 080 to 090: avg. loss: 0.4896, accuracy: 86.34%.
#   Batches 090 to 100: avg. loss: 0.4963, accuracy: 86.08%.
#
# 	Validating for epoch 25...
# 	Accurately classified 90% of 832 images.
#
# Epoch 26 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5330, accuracy: 84.84%.
#   Batches 010 to 020: avg. loss: 0.4837, accuracy: 85.55%.
#   Batches 020 to 030: avg. loss: 0.4677, accuracy: 86.25%.
#   Batches 030 to 040: avg. loss: 0.4777, accuracy: 85.70%.
#   Batches 040 to 050: avg. loss: 0.4856, accuracy: 85.59%.
#   Batches 050 to 060: avg. loss: 0.4871, accuracy: 85.70%.
#   Batches 060 to 070: avg. loss: 0.4967, accuracy: 85.74%.
#   Batches 070 to 080: avg. loss: 0.4983, accuracy: 85.68%.
#   Batches 080 to 090: avg. loss: 0.5015, accuracy: 85.82%.
#   Batches 090 to 100: avg. loss: 0.5015, accuracy: 85.83%.
#
# 	Validating for epoch 26...
# 	Accurately classified 90% of 832 images.
#
# Epoch 27 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.3986, accuracy: 87.03%.
#   Batches 010 to 020: avg. loss: 0.4074, accuracy: 87.03%.
#   Batches 020 to 030: avg. loss: 0.4194, accuracy: 86.98%.
#   Batches 030 to 040: avg. loss: 0.4509, accuracy: 86.76%.
#   Batches 040 to 050: avg. loss: 0.4482, accuracy: 86.56%.
#   Batches 050 to 060: avg. loss: 0.4534, accuracy: 86.38%.
#   Batches 060 to 070: avg. loss: 0.4493, accuracy: 86.63%.
#   Batches 070 to 080: avg. loss: 0.4587, accuracy: 86.52%.
#   Batches 080 to 090: avg. loss: 0.4547, accuracy: 86.77%.
#   Batches 090 to 100: avg. loss: 0.4565, accuracy: 86.83%.
#
# 	Validating for epoch 27...
# 	Accurately classified 91% of 832 images.
#
# Epoch 28 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4253, accuracy: 87.50%.
#   Batches 010 to 020: avg. loss: 0.4387, accuracy: 87.19%.
#   Batches 020 to 030: avg. loss: 0.4324, accuracy: 87.45%.
#   Batches 030 to 040: avg. loss: 0.4548, accuracy: 86.80%.
#   Batches 040 to 050: avg. loss: 0.4504, accuracy: 86.94%.
#   Batches 050 to 060: avg. loss: 0.4736, accuracy: 86.43%.
#   Batches 060 to 070: avg. loss: 0.4694, accuracy: 86.63%.
#   Batches 070 to 080: avg. loss: 0.4673, accuracy: 86.50%.
#   Batches 080 to 090: avg. loss: 0.4644, accuracy: 86.51%.
#   Batches 090 to 100: avg. loss: 0.4593, accuracy: 86.73%.
#
# 	Validating for epoch 28...
# 	Accurately classified 89% of 832 images.
#
# Epoch 29 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5380, accuracy: 86.56%.
#   Batches 010 to 020: avg. loss: 0.4913, accuracy: 87.03%.
#   Batches 020 to 030: avg. loss: 0.4770, accuracy: 87.45%.
#   Batches 030 to 040: avg. loss: 0.4695, accuracy: 87.19%.
#   Batches 040 to 050: avg. loss: 0.4798, accuracy: 86.78%.
#   Batches 050 to 060: avg. loss: 0.4784, accuracy: 86.80%.
#   Batches 060 to 070: avg. loss: 0.4758, accuracy: 86.72%.
#   Batches 070 to 080: avg. loss: 0.4728, accuracy: 86.78%.
#   Batches 080 to 090: avg. loss: 0.4786, accuracy: 86.48%.
#   Batches 090 to 100: avg. loss: 0.4749, accuracy: 86.59%.
#
# 	Validating for epoch 29...
# 	Accurately classified 90% of 832 images.
#
# Epoch 30 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4822, accuracy: 86.41%.
#   Batches 010 to 020: avg. loss: 0.4958, accuracy: 86.80%.
#   Batches 020 to 030: avg. loss: 0.4708, accuracy: 87.08%.
#   Batches 030 to 040: avg. loss: 0.4631, accuracy: 87.70%.
#   Batches 040 to 050: avg. loss: 0.4629, accuracy: 87.69%.
#   Batches 050 to 060: avg. loss: 0.4734, accuracy: 87.40%.
#   Batches 060 to 070: avg. loss: 0.4762, accuracy: 87.39%.
#   Batches 070 to 080: avg. loss: 0.4804, accuracy: 87.23%.
#   Batches 080 to 090: avg. loss: 0.4790, accuracy: 87.27%.
#   Batches 090 to 100: avg. loss: 0.4787, accuracy: 87.25%.
#
# 	Validating for epoch 30...
# 	Accurately classified 90% of 832 images.
#
# Epoch 31 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.5119, accuracy: 87.50%.
#   Batches 010 to 020: avg. loss: 0.5123, accuracy: 86.17%.
#   Batches 020 to 030: avg. loss: 0.5179, accuracy: 85.89%.
#   Batches 030 to 040: avg. loss: 0.5050, accuracy: 86.45%.
#   Batches 040 to 050: avg. loss: 0.4933, accuracy: 86.81%.
#   Batches 050 to 060: avg. loss: 0.4805, accuracy: 87.06%.
#   Batches 060 to 070: avg. loss: 0.4820, accuracy: 87.01%.
#   Batches 070 to 080: avg. loss: 0.4771, accuracy: 86.99%.
#   Batches 080 to 090: avg. loss: 0.4687, accuracy: 87.26%.
#   Batches 090 to 100: avg. loss: 0.4607, accuracy: 87.41%.
#
# 	Validating for epoch 31...
# 	Accurately classified 92% of 832 images.
#
# Epoch 32 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4038, accuracy: 88.59%.
#   Batches 010 to 020: avg. loss: 0.4268, accuracy: 88.75%.
#   Batches 020 to 030: avg. loss: 0.4403, accuracy: 88.39%.
#   Batches 030 to 040: avg. loss: 0.4666, accuracy: 87.42%.
#   Batches 040 to 050: avg. loss: 0.4696, accuracy: 86.94%.
#   Batches 050 to 060: avg. loss: 0.4588, accuracy: 87.08%.
#   Batches 060 to 070: avg. loss: 0.4645, accuracy: 86.96%.
#   Batches 070 to 080: avg. loss: 0.4606, accuracy: 86.97%.
#   Batches 080 to 090: avg. loss: 0.4530, accuracy: 87.03%.
#   Batches 090 to 100: avg. loss: 0.4479, accuracy: 87.06%.
#
# 	Validating for epoch 32...
# 	Accurately classified 91% of 832 images.
#
# Epoch 33 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4867, accuracy: 86.72%.
#   Batches 010 to 020: avg. loss: 0.4727, accuracy: 86.48%.
#   Batches 020 to 030: avg. loss: 0.4494, accuracy: 87.14%.
#   Batches 030 to 040: avg. loss: 0.4579, accuracy: 86.84%.
#   Batches 040 to 050: avg. loss: 0.4509, accuracy: 86.81%.
#   Batches 050 to 060: avg. loss: 0.4435, accuracy: 87.06%.
#   Batches 060 to 070: avg. loss: 0.4492, accuracy: 87.01%.
#   Batches 070 to 080: avg. loss: 0.4454, accuracy: 87.19%.
#   Batches 080 to 090: avg. loss: 0.4470, accuracy: 87.07%.
#   Batches 090 to 100: avg. loss: 0.4451, accuracy: 87.09%.
#
# 	Validating for epoch 33...
# Validation loss decreased (285.290436 --> 277.382451).  Saving model ...
# 	Accurately classified 91% of 832 images.
#
# Epoch 34 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4409, accuracy: 86.72%.
#   Batches 010 to 020: avg. loss: 0.4633, accuracy: 86.09%.
#   Batches 020 to 030: avg. loss: 0.4602, accuracy: 86.77%.
#   Batches 030 to 040: avg. loss: 0.4453, accuracy: 87.27%.
#   Batches 040 to 050: avg. loss: 0.4395, accuracy: 87.38%.
#   Batches 050 to 060: avg. loss: 0.4474, accuracy: 87.27%.
#   Batches 060 to 070: avg. loss: 0.4508, accuracy: 87.28%.
#   Batches 070 to 080: avg. loss: 0.4519, accuracy: 87.29%.
#   Batches 080 to 090: avg. loss: 0.4474, accuracy: 87.38%.
#   Batches 090 to 100: avg. loss: 0.4513, accuracy: 87.19%.
#
# 	Validating for epoch 34...
# 	Accurately classified 91% of 832 images.
#
# Epoch 35 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.3913, accuracy: 88.28%.
#   Batches 010 to 020: avg. loss: 0.3934, accuracy: 88.67%.
#   Batches 020 to 030: avg. loss: 0.4236, accuracy: 88.02%.
#   Batches 030 to 040: avg. loss: 0.4101, accuracy: 88.55%.
#   Batches 040 to 050: avg. loss: 0.4193, accuracy: 88.22%.
#   Batches 050 to 060: avg. loss: 0.4283, accuracy: 87.92%.
#   Batches 060 to 070: avg. loss: 0.4359, accuracy: 87.72%.
#   Batches 070 to 080: avg. loss: 0.4471, accuracy: 87.40%.
#   Batches 080 to 090: avg. loss: 0.4434, accuracy: 87.43%.
#   Batches 090 to 100: avg. loss: 0.4453, accuracy: 87.39%.
#
# 	Validating for epoch 35...
# 	Accurately classified 91% of 832 images.
#
# Epoch 36 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4302, accuracy: 87.66%.
#   Batches 010 to 020: avg. loss: 0.4445, accuracy: 87.34%.
#   Batches 020 to 030: avg. loss: 0.4533, accuracy: 87.03%.
#   Batches 030 to 040: avg. loss: 0.4358, accuracy: 87.73%.
#   Batches 040 to 050: avg. loss: 0.4477, accuracy: 87.28%.
#   Batches 050 to 060: avg. loss: 0.4444, accuracy: 87.50%.
#   Batches 060 to 070: avg. loss: 0.4426, accuracy: 87.61%.
#   Batches 070 to 080: avg. loss: 0.4495, accuracy: 87.32%.
#   Batches 080 to 090: avg. loss: 0.4446, accuracy: 87.57%.
#   Batches 090 to 100: avg. loss: 0.4444, accuracy: 87.44%.
#
# 	Validating for epoch 36...
# Validation loss decreased (277.382451 --> 275.075456).  Saving model ...
# 	Accurately classified 91% of 832 images.
#
# Epoch 37 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4109, accuracy: 88.91%.
#   Batches 010 to 020: avg. loss: 0.4222, accuracy: 87.89%.
#   Batches 020 to 030: avg. loss: 0.4267, accuracy: 87.81%.
#   Batches 030 to 040: avg. loss: 0.4314, accuracy: 87.77%.
#   Batches 040 to 050: avg. loss: 0.4407, accuracy: 87.53%.
#   Batches 050 to 060: avg. loss: 0.4443, accuracy: 87.50%.
#   Batches 060 to 070: avg. loss: 0.4400, accuracy: 87.54%.
#   Batches 070 to 080: avg. loss: 0.4480, accuracy: 87.50%.
#   Batches 080 to 090: avg. loss: 0.4458, accuracy: 87.60%.
#   Batches 090 to 100: avg. loss: 0.4538, accuracy: 87.50%.
#
# 	Validating for epoch 37...
# Validation loss decreased (275.075456 --> 254.333080).  Saving model ...
# 	Accurately classified 92% of 832 images.
#
# Epoch 38 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4611, accuracy: 87.97%.
#   Batches 010 to 020: avg. loss: 0.4796, accuracy: 86.80%.
#   Batches 020 to 030: avg. loss: 0.4665, accuracy: 87.08%.
#   Batches 030 to 040: avg. loss: 0.4490, accuracy: 87.42%.
#   Batches 040 to 050: avg. loss: 0.4328, accuracy: 87.78%.
#   Batches 050 to 060: avg. loss: 0.4311, accuracy: 87.89%.
#   Batches 060 to 070: avg. loss: 0.4384, accuracy: 87.50%.
#   Batches 070 to 080: avg. loss: 0.4461, accuracy: 87.36%.
#   Batches 080 to 090: avg. loss: 0.4428, accuracy: 87.48%.
#   Batches 090 to 100: avg. loss: 0.4441, accuracy: 87.31%.
#
# 	Validating for epoch 38...
# 	Accurately classified 91% of 832 images.
#
# Epoch 39 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.3928, accuracy: 89.53%.
#   Batches 010 to 020: avg. loss: 0.3948, accuracy: 88.67%.
#   Batches 020 to 030: avg. loss: 0.4198, accuracy: 88.44%.
#   Batches 030 to 040: avg. loss: 0.4226, accuracy: 87.97%.
#   Batches 040 to 050: avg. loss: 0.4409, accuracy: 87.41%.
#   Batches 050 to 060: avg. loss: 0.4492, accuracy: 87.19%.
#   Batches 060 to 070: avg. loss: 0.4468, accuracy: 87.25%.
#   Batches 070 to 080: avg. loss: 0.4337, accuracy: 87.62%.
#   Batches 080 to 090: avg. loss: 0.4345, accuracy: 87.57%.
#   Batches 090 to 100: avg. loss: 0.4402, accuracy: 87.33%.
#
# 	Validating for epoch 39...
# 	Accurately classified 91% of 832 images.
#
# Epoch 40 of 40
# ----------------------------
#   Batches 000 to 010: avg. loss: 0.4254, accuracy: 88.91%.
#   Batches 010 to 020: avg. loss: 0.4344, accuracy: 88.05%.
#   Batches 020 to 030: avg. loss: 0.4471, accuracy: 87.19%.
#   Batches 030 to 040: avg. loss: 0.4330, accuracy: 87.62%.
#   Batches 040 to 050: avg. loss: 0.4232, accuracy: 88.03%.
#   Batches 050 to 060: avg. loss: 0.4173, accuracy: 88.33%.
#   Batches 060 to 070: avg. loss: 0.4233, accuracy: 88.30%.
#   Batches 070 to 080: avg. loss: 0.4246, accuracy: 88.28%.
#   Batches 080 to 090: avg. loss: 0.4203, accuracy: 88.44%.
#   Batches 090 to 100: avg. loss: 0.4131, accuracy: 88.52%.
#
# 	Validating for epoch 40...
# 	Accurately classified 91% of 832 images.
# Done...

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
state = torch.load('trial.pt')

model = models.densenet121(pretrained=True)
model.classifier = state['classifier']
model.load_state_dict(state['state_dict'])
optimizer.load_state_dict(state['optimizer_dict'])
model.class_to_idx = state['class_to_idx']
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    img = Image.open(image).convert("RGB")
    transform = transforms.Compose([transforms.Resize(256),
                                   transforms.CenterCrop(224),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                        [0.229, 0.224, 0.225])])
    new_img = transform(img)
    return new_img

chk_image = process_image(valid_dir + '/1/image_06739.jpg')
type(chk_image)
# Out:
# torch.Tensor

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    model.eval()
    
    image = process_image(image_path)
    image = image.unsqueeze(0)
    
    with torch.no_grad():
        output = model.forward(image)
        prob,top_labels = torch.topk(output,topk)
        
        top_prob = prob.exp()
        
    class_to_idx_inv = {model.class_to_idx[k]: k for k in model.class_to_idx}
    mapped_classes = list()
    
    for label in top_labels.numpy()[0]:
        mapped_classes.append(class_to_idx_inv[label])
        
    return top_prob.numpy()[0], mapped_classes

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the validation accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='https://github.com/udacity/pytorch_challenge/blob/master/assets/inference_example.png?raw=1' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
chk_image_file = valid_dir + '/92/image_03063.jpg'
correct_class = cat_to_name['92']

model.cpu()
top_prob, top_classes = predict(chk_image_file, model)

label = top_classes[0]

fig = plt.figure(figsize=(6,6))
sp_img = plt.subplot2grid((15,9), (0,0), colspan=9, rowspan=9)
sp_prd = plt.subplot2grid((15,9), (9,2), colspan=5, rowspan=5)

image = Image.open(chk_image_file)
sp_img.axis('off')
sp_img.set_title(f'{cat_to_name[label]}')
sp_img.imshow(image)

labels = []
for class_idx in top_classes:
    labels.append(cat_to_name[class_idx])

yp = np.arange(5)
sp_prd.set_yticks(yp)
sp_prd.set_yticklabels(labels)
sp_prd.set_xlabel('Probability')
sp_prd.invert_yaxis()
sp_prd.barh(yp, top_prob, xerr=0, align='center', color='blue')

plt.show()
print(f'Correct classification: {correct_class}')
print(f'Correct prediction: {correct_class == cat_to_name[label]}')
# Out:
# Correct classification: bee balm
# Correct prediction: True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
state = torch.load('trial.pt')

model = models.densenet121(pretrained=True)
model.classifier = state['classifier']
model.load_state_dict(state['state_dict'])
optimizer.load_state_dict(state['optimizer_dict'])
model.class_to_idx = state['class_to_idx']
model_save_name = 'final.pt'
path = F"/content/gdrive/My Drive/{model_save_name}" 
torch.save(state, path)
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
